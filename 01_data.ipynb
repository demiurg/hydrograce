# %%
import rioxarray

# %%
# GeoTIFF of the GRACE Follow On anomoly view 
grace = rioxarray.open_rasterio("data/GRD-3_2018152-2018181_GRFO_UTCSR_BA01_0600_LND_v03.tif", masked=True)
grace.plot(size=10)

# %%
# NetCDF converted to GeoTIFF of the GRACE Follow On anomoly view 
# has a projection, and has more metadata, but projection is wrong
# units: meter
grace_nc = rioxarray.open_rasterio("data/GRD-3_2018152-2018181_GRFO_UTCSR_BA01_0600_LND_v03.nc.tif", masked=True)
grace_nc.plot(size=10)

# %%
# NetCDF converted to GeoTIFF of the GLDAS model
# units: mm
gldas = rioxarray.open_rasterio("data/GLDAS-NOAH_1deg_tws_anomaly_monthly_2018152-2018181.tif", masked=True)

# %%
gldas.plot(size=10)

# %%
# Ground Water delta
gw = grace - gldas / 1000
gw.plot(size=10)
