# %%
import rioxarray
import glob

# %%
xds = rioxarray.open_rasterio("data/GRD-3_2002095-2002120_GRAC_UTCSR_BA01_0600_LND_v03.tif", masked=True)

# %%
xds.plot()

# %%
print(xds.rio.crs)
print(xds.rio.transform())
xds2 = rioxarray.open_rasterio("data/GLDAS-NOAH_1deg_tws_anomaly_monthly_2019335-2019365.nc", masked=True)
# Out:
# EPSG:4326
# | 1.00, 0.00,-180.00|
# | 0.00,-1.00, 90.00|
# | 0.00, 0.00, 1.00|
# /Users/pavel/Documents/jupyter/hydrograce/.venv/lib/python3.7/site-packages/rasterio/__init__.py:219: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# /Users/pavel/Documents/jupyter/hydrograce/.venv/lib/python3.7/site-packages/rasterio/__init__.py:219: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# /Users/pavel/Documents/jupyter/hydrograce/.venv/lib/python3.7/site-packages/rasterio/__init__.py:219: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
#xds2.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-82135eeaafaf> in <module>
# ----> 1 xds2.plot()
#
# AttributeError: 'list' object has no attribute 'plot'
